# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('AAPL.csv')
df = df.drop(['Date','Adj Close'],axis=1)
df.head(10)
# Out:
#         Open       High        Low       Close     Volume
# 0  38.580002  38.610001  37.972858  266.699982  137485600
# 1  38.132858  38.535713  37.788570  268.299988  146237000
# 2  37.731430  37.770000  36.328571  256.170013  283336200
# 3  36.672855  36.852856  35.715714  251.529999  184863000
# 4  36.328571  36.400002  34.745716  248.479996  255724000
# 5  35.784286  35.847141  34.742859  246.939987  173460700
# 6  35.857143  36.114285  35.165714  248.629990  153808900
# 7  35.784286  36.967144  35.678570  258.670013  163639000
# 8  37.497143  37.557144  36.412857  258.089996  184536100
# 9  36.698570  37.128571  36.451427  259.619995  108330600

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1762.000000  1762.000000  1762.000000  1762.000000  1.762000e+03
# mean     86.665422    87.412345    85.860696   306.622435  8.442679e+07
# std      29.302855    29.488524    29.114821   189.232732  5.589370e+07
# min      34.005714    34.658573    33.651428    90.279999  1.147590e+07
# 25%      61.394643    62.099642    60.769642   115.190002  4.282875e+07
# 50%      85.651428    86.373570    84.601428   318.240021  7.090095e+07
# 75%     110.190002   111.497501   109.027499   472.592498  1.101308e+08
# max     156.009995   156.649994   155.050003   702.100037  4.702495e+08

# %%
# %matplotlib inline

# %%
plt.plot(range(len(df['Close'])),df['Close'],'g')

# %%
plt.plot(df['Open'],df['Close'],'go')

# %%
plt.plot(df['Volume'],df['Close'],'go')
